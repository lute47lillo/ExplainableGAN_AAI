# %%
# Eleuterio Juan Lillo Portero
# AAI FINAL PROJECT
# CIFAR_10 CLASSIFIER
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Mount Drive for Running on Google Colab (Coment out if running somewhere else)
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# CIFAR-10 classifier and GRAD-CAM based on generated GAN images.
# example of loading the generator model and generating images
from keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import Input, AveragePooling2D, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    
    return x_input
 
# Plot the Generated images
def create_plot(examples, n):
    # plot images
    for i in range(n * n):
        # define subplot
        pyplot.subplot(n, n, 1 + i)
        # turn off axis
        pyplot.axis('off')
        # plot raw pixel data
        pyplot.imshow(examples[i, :, :])
    pyplot.show()
 
# Load GAN model 1

# model = load_model('/content/drive/MyDrive/JUP_CIFAR10_generator_model_055.h5')


""" CGAN Classifier Training"""
# generate noise for the model prediction
samples = 10
latent_dim = 100
noise = np.random.normal(loc=0, scale=1, size=(samples, latent_dim))
labels = to_categorical(np.arange(0, 10).reshape(-1, 1), num_classes=10)
        
# generate images
x_pred = model.predict([noise, labels])
x_pred1 = np.clip(x_pred, -1, 1)
x_pred1 = (x_pred1 + 1) * 127
x_pred1 = np.round(x_pred1).astype('uint8')

# Generate images
latent_points = generate_latent_points(100, 100)

# Generate images
X_train_conc = model.predict(latent_points)
for _ in range(49):
    X_train = model.predict(latent_points)
    X_train_conc = np.concatenate((X_train, X_train_conc))

print('Shape of x_train is {}'.format(X_train_conc.shape))
# scale from [-1,1] to [0,1]
X = (X_train_conc + 1) / 2.0

# plot the result
create_plot(X, 10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 7ms/step
# Shape of x_train is (5000, 32, 32, 3)

# %%
# Pre-porcessing the Cifar_10 DATA
(x_train, y_train), (x_test, y_test)=cifar10.load_data()

y_train = y_train[:10000]
x_test = x_test[:2000]
y_test = y_test[:2000]
x_train = x_train[:10000]

final_x_train = np.concatenate((X_train_conc, x_train))
x_train = x_train[:10000]
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)
# After
# Shape of final_x_train is (15000, 32, 32, 3)
#
# Shape of x_test is (2000, 32, 32, 3)
# Shape of y_train is (10000, 1)
# Shape of y_test is (2000, 1)

# %%
# Normalizing Training and testing data
x_train=x_train/255
#final_x_train= final_x_train/255
x_test=x_test/255

# One hot encoding for 10 class labels
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
# Basic cifar_10 classifier w/ 0.93 accuracy
def cifar10_classifier():
    classifier = Sequential()
    
    classifier.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    classifier.add(BatchNormalization())
    
    classifier.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.2))
    
    classifier.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.3))
    
    classifier.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.4))
    
    classifier.add(Flatten())
    
    classifier.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    classifier.add(BatchNormalization())
    classifier.add(Dropout(0.5))
    
    # Output layer of 10 classes from Cifar_10 dataset
    classifier.add(Dense(10, activation='softmax'))
    
    # compile model
    classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    classifier_hist = classifier.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
    
    return classifier_hist, classifier

# %%
# Run and construct classifier
hist, classifier = cifar10_classifier()
classifier.save('/content/drive/MyDrive/cifar_10_class.h5')
# Out:
# Epoch 1/50
# 313/313 [==============================] - 4s 9ms/step - loss: 2.1764 - accuracy: 0.3022 - val_loss: 1.8815 - val_accuracy: 0.3095
# Epoch 2/50
# 313/313 [==============================] - 3s 8ms/step - loss: 1.6010 - accuracy: 0.4282 - val_loss: 1.3829 - val_accuracy: 0.5140
# Epoch 3/50
# 313/313 [==============================] - 3s 9ms/step - loss: 1.3806 - accuracy: 0.5000 - val_loss: 1.2090 - val_accuracy: 0.5710
# Epoch 4/50
# 313/313 [==============================] - 3s 8ms/step - loss: 1.2550 - accuracy: 0.5492 - val_loss: 1.2008 - val_accuracy: 0.5800
# Epoch 5/50
# 313/313 [==============================] - 3s 8ms/step - loss: 1.1543 - accuracy: 0.5832 - val_loss: 1.0444 - val_accuracy: 0.6240
# Epoch 6/50
# 313/313 [==============================] - 3s 8ms/step - loss: 1.0801 - accuracy: 0.6156 - val_loss: 1.0452 - val_accuracy: 0.6240
# Epoch 7/50
# 313/313 [==============================] - 3s 8ms/step - loss: 1.0312 - accuracy: 0.6351 - val_loss: 0.9821 - val_accuracy: 0.6535
# Epoch 8/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9399 - accuracy: 0.6727 - val_loss: 1.0100 - val_accuracy: 0.6465
# Epoch 9/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8710 - accuracy: 0.6924 - val_loss: 0.9580 - val_accuracy: 0.6575
# Epoch 10/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8502 - accuracy: 0.7002 - val_loss: 0.8742 - val_accuracy: 0.6845
# Epoch 11/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8140 - accuracy: 0.7133 - val_loss: 0.9218 - val_accuracy: 0.6865
# Epoch 12/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.7582 - accuracy: 0.7364 - val_loss: 0.9997 - val_accuracy: 0.6505
# Epoch 13/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.7045 - accuracy: 0.7572 - val_loss: 0.8941 - val_accuracy: 0.6890
# Epoch 14/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6768 - accuracy: 0.7621 - val_loss: 0.8310 - val_accuracy: 0.7140
# Epoch 15/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6304 - accuracy: 0.7815 - val_loss: 0.7958 - val_accuracy: 0.7285
# Epoch 16/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6082 - accuracy: 0.7896 - val_loss: 0.8605 - val_accuracy: 0.7125
# Epoch 17/50
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5879 - accuracy: 0.7937 - val_loss: 0.8279 - val_accuracy: 0.7230
# Epoch 18/50
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5430 - accuracy: 0.8121 - val_loss: 0.9025 - val_accuracy: 0.7220
# Epoch 38/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2555 - accuracy: 0.9097 - val_loss: 0.9719 - val_accuracy: 0.7610
# Epoch 39/50
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2208 - accuracy: 0.9223 - val_loss: 0.9509 - val_accuracy: 0.7510
# Epoch 40/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2225 - accuracy: 0.9226 - val_loss: 0.9281 - val_accuracy: 0.7550
# Epoch 41/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2232 - accuracy: 0.9246 - val_loss: 0.9542 - val_accuracy: 0.7560
# Epoch 42/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2194 - accuracy: 0.9269 - val_loss: 0.9747 - val_accuracy: 0.7460
# Epoch 43/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2178 - accuracy: 0.9243 - val_loss: 0.9552 - val_accuracy: 0.7520
# Epoch 44/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1986 - accuracy: 0.9324 - val_loss: 0.9556 - val_accuracy: 0.7605
# Epoch 45/50
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2066 - accuracy: 0.9280 - val_loss: 0.9821 - val_accuracy: 0.7515
# Epoch 46/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2031 - accuracy: 0.9300 - val_loss: 1.0065 - val_accuracy: 0.7550
# Epoch 47/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1925 - accuracy: 0.9371 - val_loss: 0.9355 - val_accuracy: 0.7705
# Epoch 48/50
# 313/313 [==============================] - 2s 8ms/step - loss: 0.1881 - accuracy: 0.9371 - val_loss: 0.9675 - val_accuracy: 0.7590
# Epoch 49/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1885 - accuracy: 0.9321 - val_loss: 0.9628 - val_accuracy: 0.7695
# Epoch 50/50
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1888 - accuracy: 0.9349 - val_loss: 0.9640 - val_accuracy: 0.7615

# %%
# Example Pediction from the newly constructed classifier
# label mapping
labels = ['airplane', 'automobile', 'bird', 'cat', 'deerdog', 'frog', 'horseship', 'truck']

# Select the image from our test dataset
image_number = np.random.randint(0,99)

# Generates 100 images frmo the pre-trained GAN model.
x_pred = model.predict(latent_points)

# Display the image
pyplot.imshow(x_pred[image_number])

# Load the image in an array
img = np.array(x_pred[image_number])

# Reshape it
p = img.reshape(1, 32, 32, 3)

# Pass in the network for prediction and
# Save the predicted label
predicted_label = labels[classifier.predict(p).argmax()]

# Display the result
print("Original label is {} and predicted label is {}".format(original_label, predicted_label))
# Out:
# 4/4 [==============================] - 0s 7ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1/1 [==============================] - 0s 17ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-830b4ace7330> in <module>
#      22
#      23 # load the original label
# ---> 24 original_label = labels[y_test[image_number].argmax()]
#      25
#      26 # display the result
#
# IndexError: list index out of range
