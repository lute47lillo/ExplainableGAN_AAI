# %%
# CIFAR-10 classifier and GRAD-CAM based on generated GAN images.
# example of loading the generator model and generating images
from keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import Input, AveragePooling2D, Activation, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras import regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
    
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input
 
# plot the generated images
def create_plot(examples, n):
    # plot images
    for i in range(n * n):
        # define subplot
        pyplot.subplot(n, n, 1 + i)
        # turn off axis
        pyplot.axis('off')
        # plot raw pixel data
        pyplot.imshow(examples[i, :, :])
    pyplot.show()
 
# load model
model = load_model('/Users/lutelillo/Desktop/JUP_CIFAR10_generator_model_052.h5')

# generate images
latent_points = generate_latent_points(100, 100)

# generate images
X_train_conc = model.predict(latent_points)
for _ in range(49):
    X_train = model.predict(latent_points)
    X_train_conc = np.concatenate((X_train, X_train_conc))

print('Shape of x_train is {}'.format(X_train_conc.shape))
# scale from [-1,1] to [0,1]
X = (X_train_conc + 1) / 2.0

# plot the result
create_plot(X, 10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 1s 78ms/step
# 4/4 [==============================] - 0s 88ms/step
# 4/4 [==============================] - 0s 85ms/step
# 4/4 [==============================] - 0s 101ms/step
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 0s 101ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 91ms/step
# 4/4 [==============================] - 0s 80ms/step
# 4/4 [==============================] - 1s 101ms/step
# 4/4 [==============================] - 0s 82ms/step
# 4/4 [==============================] - 0s 93ms/step
# 4/4 [==============================] - 0s 84ms/step
# 4/4 [==============================] - 0s 93ms/step
# 4/4 [==============================] - 1s 104ms/step
# 4/4 [==============================] - 0s 94ms/step
# 4/4 [==============================] - 0s 95ms/step
# 4/4 [==============================] - 0s 80ms/step
# 4/4 [==============================] - 0s 92ms/step
# 4/4 [==============================] - 1s 123ms/step
# 4/4 [==============================] - 0s 74ms/step
# 4/4 [==============================] - 0s 102ms/step
# 4/4 [==============================] - 0s 87ms/step
# 4/4 [==============================] - 0s 84ms/step
# 4/4 [==============================] - 1s 103ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 92ms/step
# 4/4 [==============================] - 0s 91ms/step
# 4/4 [==============================] - 0s 85ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 0s 83ms/step
# 4/4 [==============================] - 0s 91ms/step
# 4/4 [==============================] - 0s 94ms/step
# 4/4 [==============================] - 0s 83ms/step
# 4/4 [==============================] - 0s 89ms/step
# 4/4 [==============================] - 0s 81ms/step
# 4/4 [==============================] - 0s 87ms/step
# 4/4 [==============================] - 0s 73ms/step
# 4/4 [==============================] - 0s 80ms/step
# 4/4 [==============================] - 0s 94ms/step
# 4/4 [==============================] - 0s 83ms/step
# 4/4 [==============================] - 0s 81ms/step
# 4/4 [==============================] - 0s 71ms/step
# 4/4 [==============================] - 0s 90ms/step
# 4/4 [==============================] - 0s 86ms/step
# 4/4 [==============================] - 0s 76ms/step
# 4/4 [==============================] - 0s 69ms/step
# 4/4 [==============================] - 0s 75ms/step
# 4/4 [==============================] - 0s 84ms/step
# 4/4 [==============================] - 0s 86ms/step
# Shape of x_train is (5000, 32, 32, 3)

# %%
# Data Preprocessing
(x_train, y_train), (x_test, y_test)=cifar10.load_data()
y_train = y_train[:5000]
x_test = x_test[:1000]
y_test = y_test[:1000]

print('Shape of x_train_conc is {}'.format(X_train_conc.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)
# After
# Shape of x_train_conc is (5000, 32, 32, 3)
# Shape of x_test is (1000, 32, 32, 3)
# Shape of y_train is (5000, 1)
# Shape of y_test is (1000, 1)

# %%
# Normalizing Data
x_train=x_train/255
X_train_conc=X_train_conc/255
x_test=x_test/255

# One hot encoding for categories
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
# Basic Cifar_10 Classifier
def cifar10_classifier():
    classifier = Sequential()
    
    classifier.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
    classifier.add(BatchNormalization())
    
    classifier.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.2))
    
    classifier.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.3))
    
    classifier.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPool2D((2, 2)))
    classifier.add(Dropout(0.4))
    
    classifier.add(Flatten())
    
    classifier.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    classifier.add(BatchNormalization())
    classifier.add(Dropout(0.5))
    
    # Output layer of 10 classes.
    classifier.add(Dense(10, activation='softmax'))
    
    # compile model
    classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    classifier_hist = classifier.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
    return classifier_hist, classifier

# %%
hist, classifier = cifar10_classifier()
# Out:
# Epoch 1/50
#  68/157 [===========>..................] - ETA: 17s - loss: 3.4161 - accuracy: 0.0974
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-526158d75585> in <module>
# ----> 1 hist, classifier = cifar10_classifier()
#
# <ipython-input-39-674f22e2cae6> in cifar10_classifier()
#      36     classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#      37
# ---> 38     classifier_hist = classifier.fit(X_train_conc, y_train, epochs=50, validation_data=(x_test, y_test))
#      39     return classifier_hist, classifier
#      40
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     906
#     907       with OptionalXlaContext(self._jit_compile):
# --> 908         result = self._call(*args, **kwds)
#     909
#     910       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     938       # In this case we have created variables on the first call, so we run the
#     939       # defunned version which is guaranteed to never create variables.
# --> 940       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     941     elif self._stateful_fn is not None:
#     942       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     136       (concrete_function,
#     137        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 138     return concrete_function._call_flat(
#     139         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     140
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1742         and executing_eagerly):
#    1743       # No tape is watching; skip to running the function.
# -> 1744       return self._build_call_outputs(self._inference_function.call(
#    1745           ctx, args, cancellation_manager=cancellation_manager))
#    1746     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     375       with _InterpolateFunctionError(self):
#     376         if cancellation_manager is None:
# --> 377           outputs = execute.execute(
#     378               str(self.signature.name),
#     379               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
